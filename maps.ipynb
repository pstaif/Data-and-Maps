# %% [markdown]
# # Folium: Python Maps Tutorial
#
# First, you need to install folium. Run the appropriate cell below for your environment.

# %%
# Install via pip
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting jinja2>=2.9 (from folium)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy (from folium)
#   Downloading numpy-2.4.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting requests (from folium)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting xyzservices (from folium)
#   Using cached xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->folium)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->folium)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# WARNING: Connection timed out while downloading.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# error: incomplete-download
#
# × Download failed because not enough bytes were received (0 bytes/26 kB)
# ╰─> URL: https://files.pythonhosted.org/packages/7e/50/fc9680058e63161f2f63165b84c957a0df1415431104c408e8104a3a18ef/branca-0.8.2-py3-none-any.whl
#
# note: This is an issue with network connectivity, not pip.
# hint: Consider using --resume-retries to enable download resumption.

# %%
# Install via Conda (uncomment if using conda)
# !conda install folium -c conda-forge -y

# %% [markdown]
# ### Dependencies
# Folium has the following dependencies, all of which are installed automatically:
# - branca
# - Jinja2
# - Numpy
# - Requests

# %% [markdown]
# ## Creating a map
# Here's a basic example of creating a map. In a Jupyter Notebook, you can display it by asking for the object representation.

# %%
import folium

m = folium.Map(location=(45.5236, -122.6750))
m

# %% [markdown]
# Or you can save it as an HTML file:

# %%
m.save("index.html")

# %% [markdown]
# ## Choosing a tileset
# The default tiles are set to `OpenStreetMap`, but a selection of tilesets are also built in.

# %%
folium.Map((45.5236, -122.6750), tiles="cartodb positron")

# %% [markdown]
# ## Adding markers
# There are various marker types. You can add a popup, tooltip, and customize colors/icons.

# %%
m = folium.Map([45.35, -121.6972], zoom_start=12)

folium.Marker(
    location=[45.3288, -121.6625],
    tooltip="Click me!",
    popup="Mt. Hood Meadows",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    tooltip="Click me!",
    popup="Timberline Lodge",
    icon=folium.Icon(color="green"),
).add_to(m)

m

# %% [markdown]
# ## Vectors such as lines
# One example is `PolyLine`, which can put emphasis on a trail, a road, or a coastline.

# %%
m = folium.Map(location=[-71.38, -73.9], zoom_start=11)

trail_coordinates = [
    (-71.351871840295871, -73.655963711222626),
    (-71.374144382613707, -73.719861619751498),
    (-71.391042575973145, -73.784922248007007),
    (-71.400964450973134, -73.851042243124397),
    (-71.402411391077322, -74.050048183880477),
]

folium.PolyLine(trail_coordinates, tooltip="Coast").add_to(m)

m

# %% [markdown]
# ## Grouping and controlling
# You can group multiple elements in a `FeatureGroup` and toggle them with `LayerControl`.

# %%
m = folium.Map((0, 0), zoom_start=7)

group_1 = folium.FeatureGroup("first group").add_to(m)
folium.Marker((0, 0), icon=folium.Icon("red")).add_to(group_1)
folium.Marker((1, 0), icon=folium.Icon("red")).add_to(group_1)

group_2 = folium.FeatureGroup("second group").add_to(m)
folium.Marker((0, 1), icon=folium.Icon("green")).add_to(group_2)

folium.LayerControl().add_to(m)

m

# %% [markdown]
# ## GeoJSON/TopoJSON overlays
# Folium supports overlays from URLs, file paths, and dictionaries.

# %%
import requests

m = folium.Map(tiles="cartodbpositron")

geojson_data = requests.get(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/world_countries.json"
).json()

folium.GeoJson(geojson_data, name="hello world").add_to(m)
folium.LayerControl().add_to(m)

m

# %% [markdown]
# ## Choropleth maps
# Choropleth can be created by binding data between Pandas DataFrames and JSON geometries.

# %%
import pandas

state_geo = requests.get(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/us_states.json"
).json()
state_data = pandas.read_csv(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/us_unemployment_oct_2012.csv"
)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
).add_to(m)

folium.LayerControl().add_to(m)

m
