# %%
import censusdis.data as ced
import censusdis.maps as cem
from censusdis.states import NY
import pandas as pd
# Out:
# Traceback (most recent call last):
#
#   Cell In[2], line 1
#     import censusdis.data as ced
#
# ModuleNotFoundError: No module named 'censusdis'

# %% [raw]
# ACS variables list: https://api.census.gov/data/2022/acs/acs1/variables.html

# %%
vars = pd.read_csv("variables.csv")

# %%
YEAR = 2020
DATASET = "acs/acs5"
VARIABLE = "B19013_001E"
